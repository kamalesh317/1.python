# %%
Print Statement

# %%
print("Welcome to the Assignments-1")
# Out:
# Welcome to the Assignments-1

# %%
Addition

# %%
Num1 = 10
Num2 = 30
Add = Num1 + Num2
print("Num1=",Num1,"\nNum2=",Num2, "\nAdd=",Add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
Body Mass Index

# %%
BMI= float(input("Enter the BMI Index:"))
if BMI<18.5:
 print("Under Weight")
elif BMI<25:
 print("Healthy Weight")
elif BMI<30:
 print("Overweight")
else:
 print("Very Overweight")
# Out:
# Enter the BMI Index: 34
# Very Overweight
